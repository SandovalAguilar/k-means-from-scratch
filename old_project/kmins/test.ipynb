# %%
import kmins as k
from kmins.methods import elbow_method
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 2
#       1 import kmins as k
# ----> 2 from kmins.methods import elbow_method
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'kmins.methods'; 'kmins' is not a package

# %%
# Simulación de datos
np.random.seed(21212)

x1 = np.random.standard_normal((100, 2)) * 0.6 + np.ones((100, 2))
x2 = np.random.standard_normal((100, 2)) * 0.5 - np.ones((100, 2))
x3 = np.random.standard_normal((100, 2)) * 0.4 - 2 * np.ones((100, 2)) + 5
X = np.concatenate((x1, x2, x3), axis=0)

plt.plot(X[:, 0], X[:, 1], 'k.')
plt.show()

# Escalado
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# K-means
kmeans = k.KMins(k=3, max_iter=500, tol=1e-3)
kmeans.ajustar(X_scaled)

# Evaluación del rendimiento
score_silhouette = silhouette_score(X_scaled, kmeans.etiquetas)
print("Índice Silhouette:", score_silhouette)

# Visualización
kmeans.visualizar(X_scaled)
# Out:
# Índice Silhouette: 0.673987875005237

# %%
# Escalado
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar el método del codo
sse = k.metodo_del_codo(X_scaled, max_k=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       3 X_scaled = scaler.fit_transform(X)
#       5 # Aplicar el método del codo
# ----> 6 sse = k.metodo_del_codo(X_scaled, max_k=10)
#
# AttributeError: module 'kmins' has no attribute 'metodo_del_codo'
